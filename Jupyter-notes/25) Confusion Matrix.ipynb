# %% [markdown]
# # Confusion Matrix

# %% [markdown]
# * Some time our model will have high accuracy but stil the model will get rejected
# * What is the problem
# * By confusion matrix e will get to knwo in what all cases our model has been failed (checks for every cases)
# * ![image.png](attachment:3c9d16b2-9d8b-46c2-8460-bdc67f7fdf05.png)

# %% [markdown]
# * **Confusion Matrix** : Matrix designed using real values and predicted values
# * ![image.png](attachment:57a92e77-fef1-4d89-a0a4-b6031e888d1c.png)
# * True Negative (TN)  :
# * True Positive (PN)  :
# * False Negative (FN) :
# * False Positive (FP) :
#
# * So here the accuracy is calculated by = $ \frac{TP + TN}{TP + TN + FP + FN} $
#
# * Error = $ \frac{FP + FN}{TP + TN + FP + FN} $
#
# * So the model will get rejected because in medical industry we cannot afford FN (i.e even if fever is their and if the model tells no fever then...)
# * So the model gets rejected just because of FN and FP
#
# * ![image.png](attachment:d1d36422-caef-4e31-9dec-c1a060f165d8.png)

# %% [markdown]
# # Confusion Matrix
# *(Sensitivity, Precision, Recall, F1-score)*

# %% [markdown]
# * Here A and B are two different model on same problem statement
# * ![image.png](attachment:1bf3ba4f-f38a-42e7-81b5-dc6c973818d8.png)

# %% [markdown]
# * So now how to make the values of FN '0' or minimum
# * Through Precision
# * That is if pricision is *high* then false negative value will be *less*
# * ![image.png](attachment:44149f53-5d59-4506-8de8-bbcd4f80fc33.png)

# %% [markdown]
# And we need to increse the recall value
# ![image.png](attachment:43a1633b-ac62-493f-8694-706dc5388374.png)

# %% [markdown]
# **For precision**
# ![image.png](attachment:d4948816-5504-4d2b-b015-26e81df66de3.png)
# Here we need to decrease the FP

# %% [markdown]
# Summary :
# * For dealing with FN : Recall should be high
# * For dealing with FP : Precision should be high

# %% [markdown]
# # F1-Score
# * Abow we ahve sa that we had domain knowledge so only we can direclty say either we need to increase recall and precision
# * So when we dont had domain knowledge then we will use F1-Score

# %% [markdown]
# * We need to increase the F1-score cause it take both into account and takes the best mean of them
# * ![image.png](attachment:2aad9e48-000c-495b-8fe6-dd4ea26b9934.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"D:\Data Science\Datasets\placement-dataset.csv")
data.drop(columns=['Unnamed: 0'], inplace=True)

# %%
data.head(3)
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0

# %% [markdown]
# Depentent and independant variable

# %%
x = data.iloc[:,:-1]
y = data['placement']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, train_size=0.8, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test, y_test)
# Out:
# 0.85

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score,f1_score

# %% [markdown]
# # confusion matrix

# %%
confusion_matrix(y_test, lr.predict(x_test))
# Out:
# array([[9, 1],
#        [2, 8]], dtype=int64)

# %%
cm = confusion_matrix((y_test), lr.predict(x_test))
sns.heatmap(cm, annot = True)
# Out:
# <Axes: >

# %% [markdown]
# # Precision and recall

# %%
precision_score(y_test, lr.predict(x_test))
# Out:
# 0.8888888888888888

# %% [markdown]
# # Recall Score

# %%
recall_score(y_test, lr.predict(x_test))
# Out:
# 0.8

# %% [markdown]
# # F1-Score

# %%
f1_score(y_test, lr.predict(x_test))
# Out:
# 0.8421052631578947
