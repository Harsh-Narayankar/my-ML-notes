# %% [markdown]
# # Cost Function

# %% [markdown]
# * Used to make best fit line
# * It finds the error and then takes the model which has minumumn error

# %% [markdown]
# Cost function vs Lose Fuction
# * Lose function is used when we are using sigle row
# * Cost function is used when their are multiple rows (sklearn uses this only)
# * ![image.png](attachment:cc12783d-baa5-4385-ab4c-b1ddf9e57081.png)

# %% [markdown]
# ![image.png](attachment:45638c49-321e-4796-8061-4a465ad59fd1.png)

# %% [markdown]
# ![image.png](attachment:224aa5b5-5460-4299-930a-f32bd364de8c.png)

# %% [markdown]
# # Regreesion cost function

# %% [markdown]
# Cost function is used to decrease the error
# 3 Types
#     1) Mean square error
#     2) Mean Absolute error
#     3) Root mean square error
#     ![image.png](attachment:ef370b37-d8cb-4560-961a-c973e030eca5.png)

# %% [markdown]
# # Mean Square Error

# %% [markdown]
# How to find best fit line
# Through iteration using mse as lose and redusing the error thorugh learning rate
# * As the mse is a defferenciable equation then we can find the defferenciation of it for the minimumn value
# * And it is a sqaure equation so we will get a parabola and ill mve towards the bottom using gradient decendent using learning rate
# * ![image.png](attachment:061c3f23-166a-42b9-b133-568a996ff412.png)

# %% [markdown]
# * MSE is robust (pron) to error
# * It will shift very much for any outlier (robuss) because it is getting sqaured
# * Error is in terms of square form  e5 = 25cm^2

# %% [markdown]
# # Mean absolute error
#
# * Differece beteen this ans mse is, it uses mode insted of sqaure
# * That is it will gove positive even if the error is negative
# * prons is it will gove error in its actual unit
# * ![image.png](attachment:1a789d57-a35b-4cb9-b76a-c13038a41d08.png)
# * ![image.png](attachment:7c437807-36df-4e17-b20a-ef6b7c88b594.png)
# * This will works good with outliers ( i.e it wont shift much (less shift)) becouse it wont get squared
# * cons : It is not a defferential eqaution ( becaouse of sharp corner point) so we cant get the exact minimum

# %% [markdown]
# # Root mean sqaure error
# * square root of mse
# * This help in retaining original unit of error
# * ![image.png](attachment:8ec363ca-d337-4299-9461-83cd9cdcc10e.png)
