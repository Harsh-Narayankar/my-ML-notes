# %% [markdown]
# # Batch Normalization
# Normalization refers to adjusting values measured on different scales to a common scale, often between 0 and 1 or with zero mean and unit variance.

# %% [markdown]
# * So in the hidden layer the nodes revie data which is not normalised which causes vernise gradient deseint
# * ie we need to normalise the input data before coming to the neuron>

# %% [markdown]
# Refer the privious file and just add **BatchNormalization** between the layers (no after the last)

# %% [markdown]
# ![image.png](attachment:6cc3c04d-0624-437c-b59d-682570e03462.png)

# %% [markdown]
# ![image.png](attachment:5fe1db1d-1119-4e47-88db-e7f007f001a0.png)
