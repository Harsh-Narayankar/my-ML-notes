# %% [markdown]
# # Convolution Neural Network

# %% [markdown]
# * This is used when we are training model through images
# * We can also train images in ANN by we need to give it as number ie encode it in numbers. But the= accuracy will be less

# %% [markdown]
# ![image.png](attachment:3722b859-e8e9-46cb-b385-75c47911a845.png)

# %% [markdown]
# * Image consits of many pixel and we cant train whole image at once
# * So we will use *Pooling layer* after the *Convolution layer* iterativly
# * The **Pooling Layer** will comprese the pixel which is gotten by convolution layer
# * After this process the data is sent to ANN network or **Fully connected layer**
# * ![image.png](attachment:bcf0ad6c-ae16-456a-8896-17b22600bc05.png)

# %% [markdown]
# **Different between ANN and CNN**
# * The data comes in ANN is row number format
# * While in CNN it is of image

# %% [markdown]
# ![image.png](attachment:363e41d6-f1dc-4061-a0b2-df7c60cc3893.png)

# %% [markdown]
# ![image.png](attachment:fad8de30-0562-4618-b5d0-cc5af995c388.png)
# Here the flattering is making the matrix into simple row to pass that into input of ANN

# %% [markdown]
# # Convolution

# %% [markdown]
# * The role of convolution is to extract features from it by detecting the edges
# * ![image.png](attachment:ee91523a-ff2c-433a-a442-7e5150edee64.png)

# %% [markdown]
# Here kernal is used to extract the feature
# ![image.png](attachment:dd791a6f-4b0a-4c55-965c-783d5ae09b6d.png)

# %% [markdown]
# # Pooling

# %% [markdown]
# * Reason of using this to reduce the size of an image of extracting only important features
# * Also this is used to enhance the image
# * ![image.png](attachment:cf6c25be-7b13-4251-af32-94372ec74ea9.png)

# %% [markdown]
# ![image.png](attachment:2587b049-6401-4a28-a7a4-104cbb257c4e.png)

# %% [markdown]
# # Flattering

# %% [markdown]
# This changes the result matrix after convolution and flattering into a row to use it as a input to ANN
# ![image.png](attachment:25bca2c6-05f8-4d9d-aa4c-8c405478a7a5.png)

# %% [markdown]
# ![image.png](attachment:3770632a-6d91-4a74-83a6-a4357bae58b4.png)

# %% [markdown]
# **Practical**

# %% [markdown]
# ![image.png](attachment:d21f41a3-9fd1-4fec-bf89-4cff9a10f216.png)
# ![Screenshot 2025-07-24 173223.png](attachment:088369a3-d16f-4530-9fc4-50ab2a8c81e2.png)
# ![image.png](attachment:5fbed7de-0697-4bb3-bc0f-7f2c87b9d36a.png)
# This is training 200 images in 1 epoch

# %% [markdown]
# **To test**
# ![image.png](attachment:4026b2a2-5042-4ff7-815c-e5879e7011a3.png)
# ![image.png](attachment:87edae39-c460-4173-b70d-2564ef076625.png)
