# %% [markdown]
# # How to find best fit line

# %% [markdown]
# ![image.png](attachment:45e5f124-1b6c-46fa-8791-f535f08af2b9.png)
# * Gradient decent
# * Choise random pont and then go near the best point using learning rate and updating wieght and intecept through minimising the lose
# * ![image.png](attachment:18f2e0b9-700e-482d-b868-f494a362f3f9.png)
