# %% [markdown]
# # Polynimial Regression
#
# * When the data dons,nt follows polynimial realtion
# * ![image.png](attachment:083ee5f0-8fc5-48e1-a2d8-8726c34dab72.png)
# * ![image.png](attachment:7ef54fb6-2c42-4b2c-8649-1965070a4d04.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("D:\Data Science\Datasets\salary.csv")
# data.drop('Position', axis=1, inplace=True)
data
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Harsh Narayankar\AppData\Local\Temp\ipykernel_11292\3802525795.py:1: SyntaxWarning: invalid escape sequence '\D'
#   data = pd.read_csv("D:\Data Science\Datasets\salary.csv")
#             Position  Level    Salary
# 0   Business Analyst       1    45000
# 1  Junior Consultant       2    50000
# 2  Senior Consultant       3    60000
# 3            Manager       4    80000
# 4     Country Manger       5   110000
# 5     Region Manager       6   150000
# 6            Partner       7   200000
# 7     Senior Partner       8   220000
# 8            C.level       9   250000
# 9                CEO      10  1000000

# %%
data
# Out:
#             Position  Level    Salary
# 0   Business Analyst       1    45000
# 1  Junior Consultant       2    50000
# 2  Senior Consultant       3    60000
# 3            Manager       4    80000
# 4     Country Manger       5   110000
# 5     Region Manager       6   150000
# 6            Partner       7   200000
# 7     Senior Partner       8   220000
# 8            C.level       9   250000
# 9                CEO      10  1000000

# %%
x = data['Level']
# Out:
# ----------------------------------------------------------------
# KeyError                       Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Level'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 x = data['Level']
#
# ...

# %%
plt.scatter(x='Level', y='Salary', data=data)
# Out:
# ----------------------------------------------------------------
# ValueError                     Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plt.scatter(x='Level', y='Salary', data=data)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:3699, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3680 @_copy_docstring_and_deprecators(Axes.scatter)
#    3681 def scatter(
#    3682     x: float | ArrayLike,
#    (...)
#    3697     **kwargs,
#    3698 ) -> PathCollection:
# -> 3699     __ret = gca().scatter(
#    3700         x,
#    3701         y,
#    3702         s=s,
#    3703         c=c,
#    3704         marker=marker,
#    3705         cmap=cmap,
#    3706         norm=norm,
#    3707         vmin=vmin,
#    3708         vmax=vmax,
#    3709         alpha=alpha,
#    3710         linewidths=linewidths,
#    3711         edgecolors=edgecolors,
# ...

# %% [markdown]
# **Steps**
# * Convert the data into polynimial feature
#   * from sklearn import PolynimialFeatures
#   * pl = PolynmialFeatures(degree=2) #number of degree in based on the accuracy score, that is you can edit the degree accordigly
#
# * Fit and trasnform the feture
#   * pl.fit(x)
#   * x = pl.transform(x)
#
# * Split the data, train_test
#
# * now fit for LinearRegression (same as last one)
#
# * It is just that we need to alter the feature, then use LinearRegression only

# %% [markdown]
# Whenever new data comes
# * first trasnfrom the data value
#   * test = lr.trasnsfrom([[79]])
#   * lr.predict(test)
