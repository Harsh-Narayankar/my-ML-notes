# %% [markdown]
# # Assemble learning (used nowadays)
# * Assembling mnultiple models

# %% [markdown]
# * This is used to improve model

# %% [markdown]
# * Assume that you wrote a noval and ask friend to revie it and if friend said it is good and you publised. But the noval dosnt sold a peice
# * So you go you friend again a ask then he tolds that the noval was not good
#
# * So next time you come up with a solution of showing it to many different people
# * And they will give different different review
# * You will collect the review
# * if 4/5 said its a good noval then you will publise
# * but 4/5 told its bad then you ont publish

# %% [markdown]
# * So in assembel learning you will train multiple model on a single dataset
# * And you get multiple answers (output)
# *  So you will choice the answer of those who has more number of model told

# %% [markdown]
# **So combining multiple model answer and giving a single answer (more accurate) is called assemble learning**

# %% [markdown]
# ![image.png](attachment:45cb18e0-d3b9-438e-ac6a-c8e947d24068.png)

# %% [markdown]
# **Algorithm that works under assemble learning**
# ![image.png](attachment:1efcf416-9686-44f7-b30e-ec9a71bf4e2b.png)
