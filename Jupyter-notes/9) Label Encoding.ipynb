# %% [markdown]
# # Label Encoding

# %% [markdown]
# It is perfomred on nominal data
# I.E their is not connection between the data
# ex no sequence order, every data acts as individual  (buffello, cat, dog, )

# %%
import pandas as pd

# %%
df = pd.DataFrame({'name': ['cat','dog','black','honey']})
df
# Out:
#     name
# 0    cat
# 1    dog
# 2  black
# 3  honey

# %% [markdown]
# So we have a data, and now we need to do encoding of it, for that we may require sklearn library

# %%
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# fit_transform() is a common method used in data preprocessing, especially in machine learning workflows using libraries like scikit-learn.
#
# 🔍 Purpose of fit_transform():
# It combines two steps in one:
#
# fit() – Learns the parameters/statistics from the data (e.g., mean and std for scaling).
#
# transform() – Applies the learned transformation to the data.
#
# ✅ So fit_transform() is used to:
# Learn from the data and immediately apply the transformation.
#
# 🔧 Why use fit() and transform() separately?
# 1. Training vs. Test Data (Prevent Data Leakage)
# You must fit on training data only, then transform both training and test data using the same learned parameters.

# %%
le = LabelEncoder()
# fit: will train the model
# transform: will convert the model (combining both will used for training model)
le.fit_transform(df[['name']])
# Out:
# C:\Users\Harsh Narayankar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([1, 2, 0, 3])

# %%
# so now we need to attach this encodel column to our column
le.fit(df)
# Out:
# C:\Users\Harsh Narayankar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\preprocessing\_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LabelEncoder()

# %%
df['encoded value'] = le.fit_transform(df)
# Out:
# C:\Users\Harsh Narayankar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
df
# Out:
#     name  encoded value
# 0    cat              1
# 1    dog              2
# 2  black              0
# 3  honey              3

# %% [markdown]
# **Real World**

# %%
df = pd.read_csv("D:\Data Science\Datasets\shopping_trends.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Harsh Narayankar\AppData\Local\Temp\ipykernel_2300\1276558938.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df = pd.read_csv("D:\Data Science\Datasets\shopping_trends.csv")

# %%
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
# to see the unique values in 'Category'
df['Category'].unique()
# Out:
# array(['Clothing', 'Footwear', 'Outerwear', 'Accessories'], dtype=object)

# %%
# encoding Category
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
Encoded_values = le.fit_transform(df['Category'])

# %%
df.insert(5, 'Encoded Values', Encoded_values)

# %%
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  Encoded Values  \
# 0               1   55    Male         Blouse     Clothing               1
# 1               2   19    Male        Sweater     Clothing               1
# 2               3   50    Male          Jeans     Clothing               1
# 3               4   21    Male        Sandals     Footwear               2
# 4               5   45    Male         Blouse     Clothing               1
# ...           ...  ...     ...            ...          ...             ...
# 3895         3896   40  Female         Hoodie     Clothing               1
# 3896         3897   52  Female       Backpack  Accessories               0
# 3897         3898   46  Female           Belt  Accessories               0
# 3898         3899   44  Female          Shoes     Footwear               2
# 3899         3900   52  Female        Handbag  Accessories               0
#
# ...
