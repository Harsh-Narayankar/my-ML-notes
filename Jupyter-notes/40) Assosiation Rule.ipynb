# %% [markdown]
# # Association rule
# **Items bought together**
# * So in Unsuperwise learning we have two categories
# * 1) Clustering : we make groups of data with their distance while learning and when the new value comes in then by looking at the feature we can assiciate them with the perticular category
#   2) Association :
#      * Based on experiences and repeated exposure.
#      * Involves memory of past events.
#      * Helps in prediction and decision-making.
#      * For instance, a recommendation system might associate user behavior (like watching action movies) with preferences (recommending other action movies).

# %% [markdown]
# **Association Learning**: ML technique used discover interesting pattern in large dataset
# * That is used when items are bought together

# %% [markdown]
# **Technique**
# * ![image.png](attachment:76246c70-b4e2-4af9-b5fb-29a07d3d3a55.png)
# * **methods** Used to wether two product are associate or no
#   1) Support
#   2) Confidence
#   3) Lift
# Note : the target goal is to find the next product

# %% [markdown]
#  **Support** : (probability) Finds the probability that how many time the product has be buyed
#  ![image.png](attachment:1debf455-a3df-42c4-ba01-e6f58470459b.png)
#  * ![image.png](attachment:5ffab3a3-7894-4868-9b38-f988a916ca0a.png)
#  * Uses support to put a lower bond to a lesselling product
#  * i.e say S(item)<=50% then the item in not in most selling catogory
#  * Also say if S(item)<= 10% then we can remove that product from the store
#
#  * In short : Support tells how much time the  item is been buyed (i.e probabiity of buying)
#
#  * **How will you know two item are bought together**
#  * check for both the product suport(prob)
#  * Ex 1: in this case S(*Eggs and Bacon* ) = 50% above our marks so this both are being bought together
#
#  * Ex 2: S(*Bacon and Apple*) = 33% less so cant be kept togeter

# %% [markdown]
# **Confidance** (conditional probability)
# Gives us surity that the next item will be purchased, giveen that another item has been purchased
# * And Which item to set first
# * ![image.png](attachment:9ed5c4a2-b6eb-4df5-aeed-1264d8efe765.png)

# %% [markdown]
# **Lift**
# Till now we have got to know that items are bought frequntly, but we are not sure that both the  item are bought together
# So we will calculate lift values (like regression coefficient)
# ![image.png](attachment:0a61eb4d-c178-4043-80a6-6ca8c81ff684.png)

# %% [markdown]
# **Types of association rule learning Algorithm**
# 1) Apriori
# 2) Eclat
# 3) F-P Growth Algorithm

# %% [markdown]
# **Apriori Algorithm**
# ![image.png](attachment:8a94c494-2d12-43d6-b009-360398322693.png)
# * We have this ID and item bought in the form of dictionary
#
#
# *First deside the terms
# 1) Min Support = 50%
# 2) Min Confidance = 50%
# Below which we will reject

# %% [markdown]
# **Process**
# 1) We need to find support of individual product so see the frequency and remove them
# ![image.png](attachment:95860fb9-b2a5-4b7a-811c-8b85e4ee1a10.png)
# Here S(A)=20 < 50 so remove A
# * the product which has most buying frequency are (after removing those which S<50)
#   ![image.png](attachment:b81bec5c-de39-473e-bfd5-39743982e79a.png)
#
# 2) Make pair of two-two and see its Support
#    ![image.png](attachment:50216eae-9601-4c66-a8cc-602cfa1e1705.png)
#
# 3) Again make pairs of 3
#    * so at last we are left with keo only cause is s in 50%
#
#
#
# 4) Now check for the order
#    * Whether its keo/koe/oke/oek/eok/eko
#    * Through confidence ![image.png](attachment:b080bcca-67c4-479b-973d-e6992a6dcf0c.png)
#    * ie first check for ke or ek
#    * ex; for ke = total no. of ke appearing/ number of e appearing
#    * If you got KE then for next check for EO or OE
