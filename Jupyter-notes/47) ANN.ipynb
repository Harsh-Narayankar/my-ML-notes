# %% [markdown]
# # ANN (Multilayered neural network)
# * Why we reject single layer perceptron
# * When we have non-linear saparable data the single layer perceptron dosenot work good and give wrong saparable line
# * So we need to introduce myltilayer (adding lot of single layer perceptron)
# * It looks like. It has input layer , hidden layers , output layer
# * ![image.png](attachment:62246176-b0cf-4ec6-875d-5dbfbf30721b.png)
#
# * So many single layer percepton will give many saparable line
# * Like this ![image.png](attachment:9adfd1cb-6e02-4b59-b89e-d58541ba513a.png)
#
# * *Note:* The input to the hidden layer is the output of the previous layer, ie full fledged y
# * ![image.png](attachment:ebc4208a-5e39-47a1-9984-dde21898b90e.png)
# * It actually looks like this where all the previous layer are passes to every neuron in the next layer (fully connected dense layer)
# * Note: Even though all neurons in a layer receive the same set of inputs, they produce different outputs because of:
#   1) Different weight and biases
#   2) Different activation function
# * ![image.png](attachment:90ead66f-ce8f-45be-9461-d792bf6f0610.png)
# * ![image.png](attachment:3fcd707f-c0e1-41ab-9bee-a1ca37c23809.png)
# * ![image.png](attachment:3aa2a444-7b7a-4d20-baec-6f5523402c95.png)
#
# * Note: every layer equation is same yi = actv(wTx+b)
