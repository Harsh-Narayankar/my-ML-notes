# %% [markdown]
# # Loss Funstions
# * Used to find the best parametres ie less the loss best the parametres

# %% [markdown]
# * Whenever we use any algorithm then the score it the accuracy score ie correct prediction
# * But Loss function measure the wrong prediction by using the difference beteen the original data an predicted data

# %% [markdown]
# **Loss = (y-y_pred)^2**
# were : y_pred = mx+c or y_pred = w1x1+....+wnxn + b

# %% [markdown]
# **Looss function vs Cost function**
# * Know that loss function is a loss of every prediction calculated saparatly
# * So calculatig the average of all the loss is a **Cost Function**
#
# * Therefore : Cost function = 1/N(y-y_pred)^2 (same as MSE)
#
# * So Loss function - is a single point error
# * while cost functio - is average of all the point error (MSE , MAD)

# %% [markdown]
# **Types of Loss Function**
# ![image.png](attachment:6afdfe10-8036-4d32-b359-6b18eda0b194.png) ![image.png](attachment:b3a4745d-2a46-4eac-bd98-c3bc6eecb4f2.png)

# %% [markdown]
# **Mean Square Error**
# * We can use it anywhere like regression and neural network
# * MSE is defferenciable
# * Dont use this when dataset has many outlier
# * ![image.png](attachment:c7e0be53-55b4-4d3d-907c-01f4d0f2d1d2.png)

# %% [markdown]
# **Mean Absoute Error**
# * Can consider even when we have bit outliers
# * This is non-differentiable, So we dont use it often
# * And we cant get the exact value of error
# * Can consider even hen
# * ![image.png](attachment:4ef98178-2356-45fa-92ea-473aba79c1a4.png)

# %% [markdown]
# **Huber Loss**
# * When the dataset has many outliers like aroung 30%
# * ![image.png](attachment:eb4a26db-998c-462a-b194-73cf595463c3.png)
# *

# %% [markdown]
# **Classification Loss**

# %% [markdown]
# **Binary Cross Entropy / Log Loss**
# ![image.png](attachment:8d6ccc09-d492-4d01-9deb-045677b674bf.png)

# %% [markdown]
# **Categorical Cross Entropy**
# ![image.png](attachment:d6188778-bb76-4254-8956-bf2f2a165169.png)

# %% [markdown]
# **Categorical Cross Entropy**
# * When e have Many categories
# * ![image.png](attachment:55243614-ff34-4d02-aa95-4799932d28f9.png)
