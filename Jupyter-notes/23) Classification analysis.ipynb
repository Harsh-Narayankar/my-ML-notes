# %% [markdown]
# ## Classification analysis

# %% [markdown]
# ![image.png](attachment:e455f283-9282-4359-9378-588e0b5417dc.png)

# %% [markdown]
# ![image.png](attachment:7de649d3-92f8-4f45-9463-8b6ad9f7768a.png)

# %% [markdown]
# ![image.png](attachment:6072a984-52ed-4250-8ccf-3b33362127c0.png)

# %% [markdown]
# # Evaluvating the modle

# %% [markdown]
# * After we impliment the model then we have to evaluate its error so here are the ways to do so
#   1) Log loss or cross-Cross-entropy loss : This will take the losses and by using gradient desendent it helps to classify correctly
#   2) Confusion Matrix : even if the model has high accuracy some modle gets rejected to this will help to find the reason
#   3) AUC-ROC curve

# %% [markdown]
# ## Real World example
# ![image.png](attachment:89840459-00d1-4bdd-8953-91ee2e2e1781.png)
