# %% [markdown]
# # Deep learning
# * This is a subpart of ML
# * So is AL : ML, Data science, Deep learning are sub part

# %% [markdown]
# * So in ML we used to do many works like cluster and recomendation system in Unsuperwose learning
# * And prediction in Sepervised learning

# %% [markdown]
# ![image.png](attachment:b0037e76-dfda-422f-83eb-cbece225528e.png)
#
# All comes under data science

# %% [markdown]
# **Difference btw ML and DL**
# * So in ML we used to have superwise (Classification and regression) learning and Unsuperwised(Clustering and recomemdation system) learning
#
# * In deep learning we will have same works as Supervised ie classification and
# regression
#
# * ML : Algorithm (set of formula)
# * DL : Neural Networks (connection which forms a network)

# %% [markdown]
# **Deep Learning**
# * Deep Learning uses deep (multi-layered) neural networks to learn complex patterns in data
# * Deep Learning is a subfield of machine learning focused on using artificial neural networks — especially large, multi-layered ones — to model and understand complex patterns and relationships in data.
# * ![image.png](attachment:01b374be-0bea-44a8-b8cf-4dea15d0e571.png)

# %% [markdown]
# * This acts same as Human brain ie whenever we smell, touch, taste something then neurons will collect the data and sends it to mind and accumulate all the data and recognise it.
# * ![image.png](attachment:85c3aaa2-53b4-462a-90b6-572caeadd875.png)

# %% [markdown]
# **Application of Deep Learning**
# * Speech recognition
# * Autopilot
# * Image recognation
# * Translate

# %% [markdown]
# **Why are we using DL over ML**
# ![image.png](attachment:0e88fc08-90ab-41d9-870b-385b4024ecae.png)
#
#
# * Use when you have like 10k rows cause DL is data hungry

# %% [markdown]
# # Neurons
# * Whenever we touch something the all the signal is sent through neurons only
# * ![image.png](attachment:24b2436c-17b3-42ba-a270-98bf91db7b84.png)
# * Our *skin* in connected to *dendrite* which recives the signal and passes to *cell nucleus* after all the collected signal is sent to *synapase* and *mind* through *Axon*
# * Then our *mind* will create a output whether to remove our hand form the hot cup or not

# %% [markdown]
# # Artificial Neuron
# * ![image.png](attachment:c78142c6-63cf-46be-8bdc-fce1fe7626a8.png)
#   **Steps**
#
# 1) Here the input is recived by x1,x2....xn and the The number of xi = number of input features your model receives (we need to decide it based on our input data ie in housing we may require size, rooms, location)\
# 2)  And weightage is given to each xi through wi
# 3)  The like *Dendrite* all the data is collected by multiplication and summasion
# 4)  Then *Bias* is added beacuse it will
# > Increases Flexibility
# Allows the model to fit non-zero outputs even when input is zero.
# Makes the neuron more capable of shifting activation thresholds.
#
# > Enables Learning More Complex Patterns
# Helps the network adjust the position of activation functions (e.g., sigmoid, ReLU), improving learning of patterns in the data.
#
# > Avoids Oversimplified Models
# Without bias, the network may learn only a limited class of functions, reducing its ability to generalize.
#
# 5) Then all the collected data is transfered to actication function beacuse it will transfer the big linear equation into 0 and 1 in classification and [0,1] in regression
#
#
# _> This all called as *Single Layered Perceptron*

# %% [markdown]
# # Types of DL networks
# 1) Perceptron
# 2) Feed Forward Network (same as perceptron)
# 3) Multi-layered Parceptron (ANN)
# 4) Radial Based Network
# 5) Convolution Neural Network (while working on image)
# 6) Recurrent Neural Network (text rellated work) (autometic suggestion while typing)
# 7) Long Short-Term Momory network
