# %% [markdown]
# # Activation function
# * While learning single layer perceptron at the edn after multiplying ith weight and adding bias we used an activation function which scales the output as per dependancy of binary or regression
# * So till activation function the range of the function would be [-inf, +inf]
# * To scale it to the desired output we need and activation function to change the range

# %% [markdown]
# **Type of Activation function**
# 1) Binary step functino
# 2) Linear AF
# 3) Non-Linear AF (we need to use this only cause real world are non-linear)

# %% [markdown]
# **Binary Step Function**
# * This works on a threshold values above which the neuron should activated or not
# * ![image.png](attachment:0fcd70af-88a9-428a-bb6d-c59fefb5ba19.png)
# * Were x - threshold value

# %% [markdown]
# **Linear Activation Function**
# * Whatever output e are getting we need to show it without any changes
# * Its range is [-inf, +inf]
# * ![image.png](attachment:78a83202-6c52-481a-80a6-926c3bb5bf59.png)

# %% [markdown]
# # **Non-Linear Function**
# * To build model curves, logic gates, boundaries we need non-linear activation function
# * It is capable in adopting any sort of data to perform currect differentiation among the output
# * ![image.png](attachment:a062b9d2-269c-4e70-9594-36fafcddcc28.png)

# %% [markdown]
# **Types of Non-Linear activation function**
# 1) Sigmoid / Logistic AF
# 2) Tanh function (Hyperbolic Tangent)
# 3) ReLU function
# 4) Softmax Function

# %% [markdown]
# **Sigmoid**
# * ![image.png](attachment:9f6f8bfc-348a-439e-b1f9-206e5ec2b65a.png)
# * Whenever our output is 0 or 1 (binary)
# * Note: This activation function benifits is it is defferentiable, so we can use this in gradient desent
# * If the activation function is non defferentiable the we cannt use gradient decsent and cannt uptade the weight values
#
# * Note: Sigmoid is not zero centered ie its MSE cannt be zero, it is bias towards +ve
# * Great follow-up! You're absolutely right — sigmoid activation function is not zero-centered, and that has important implications for training neural networks.
#
# 🔹 What is "Zero-Centered"?
# An activation function is zero-centered if its output can be both positive and negative, and averages around zero.
#
# Example of zero-centered:
# Tanh activation outputs between
# −
# 1
# −1 and
# +
# 1
# +1, centered at 0.
#
# Example of not zero-centered:
# Sigmoid outputs between
# 0
# 0 and
# 1
# 1 — always positive.
#
# 🔹 Why Not Being Zero-Centered Is a Problem?
# It causes inefficiencies in gradient descent.
#
# Let’s break it down:
# 🔸 Sigmoid Output:
# 𝜎
# (
# 𝑥
# )
# =
# 1
# 1
# +
# 𝑒
# −
# 𝑥
# ∈
# (
# 0
# ,
# 1
# )
# σ(x)=
# 1+e
# −x
#
# 1
# ​
#  ∈(0,1)
# So:
#
# Output is always positive
#
# Mean activation value is > 0, especially when initialized
#
# 🔸 What Happens in Gradient Descent?
# Let’s say you're doing gradient descent with weight update:
#
# 𝑊
# :
# =
# 𝑊
# −
# 𝛼
# ⋅
# ∂
# 𝐿
# ∂
# 𝑊
# W:=W−α⋅
# ∂W
# ∂L
# ​
#
# In backpropagation, gradients involve activation values.
#
# If those activations are all positive, then:
#
# The gradient w.r.t. weights becomes biased in a certain direction
#
# Weight updates may oscillate, and convergence slows
#
# It’s harder to reach the minimum efficiently
#
# 🔸 Compare With Tanh:
# tanh
# ⁡
# (
# 𝑥
# )
# ∈
# (
# −
# 1
# ,
# 1
# )
# tanh(x)∈(−1,1)
# Outputs positive and negative
#
# Mean output closer to 0
#
# Gradients are more balanced → faster and more stable convergence
#
# 🔷 Summary
# Property	Sigmoid	Tanh
# Output Range	(0, 1)	(−1, 1)
# Zero-Centered	❌ No	✅ Yes
# Gradient Behavior	Biased (all +ve)	Balanced
# Training Convergence	Slower	Faster (usually)
#
# ✅ That’s why:
# Sigmoid is rarely used in hidden layers today.
#
# Preferred options are:
#
# ReLU (most common)
#
# Tanh (if zero-centered output is important)

# %% [markdown]
# **Tanh Function (hyperbolic tanget)**
# * Range [-1,1]
# * This is defferentiable and zero-centred
# * So used in hidden layes
# * In output layer, it is used for classification
# * ![image.png](attachment:779725f4-107f-4863-bc32-0d80ecc0fa53.png)

# %% [markdown]
# **SoftMax Function**
# * We saw *Sigmoid* and *Tanh* is used for binary classification.
# * And if thier are many classes like['cat', 'dog','pig','cow'] then we cant use those
# * So we use *Softmax*
# * used when output is more then two
# * ![image.png](attachment:c58068d1-7f65-41e0-9481-545bb09925f6.png)

# %% [markdown]
# **ReLU**
# * In hidden layer we cannt use linear activation funtio because of varnice gradient desect problem
# * So to stop that we use ReLU
# * ![image.png](attachment:5a50e3b6-025c-4182-8099-0af4a82f9705.png)

# %% [markdown]
# **Summary**
# * How to chose the right activation function
# ![image.png](attachment:5514d413-19da-47b1-a08c-d0f0fb84072a.png)

# %% [markdown]
# ![image.png](attachment:7d71872d-b6b1-4c33-9b8d-8fb51f75f538.png)
