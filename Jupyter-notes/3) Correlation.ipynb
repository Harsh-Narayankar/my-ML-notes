# %% [markdown]
# # 🔗 Correlation & Correlation Coefficients
#
# Correlation is a statistical technique that shows how **strongly** two variables are **related** to each other.
#
# ---
#
# ## 📘 What is Correlation?
#
# - Correlation measures the **direction** and **strength** of a **linear relationship** between two variables.
# - It does **not imply causation** — just association.
#
# ---
#
# ## 📈 Types of Correlation
#
# | Type                    | Description                                      |
# |-------------------------|--------------------------------------------------|
# | **Positive Correlation** | As X increases, Y also increases                 |
# | **Negative Correlation** | As X increases, Y decreases                      |
# | **No Correlation**       | No predictable pattern or linear relationship    |
#
# ---
#
# ## 🧮 Correlation Coefficient (r)
#
# - It is a **numeric summary** of the relationship.
# - Value of `r` lies between **-1 and +1**
#
# ### 🔢 Interpretation of r:
#
# | r Value Range       | Strength of Relationship   |
# |---------------------|-----------------------------|
# | +0.90 to +1.00      | Very strong positive        |
# | +0.70 to +0.89      | Strong positive             |
# | +0.40 to +0.69      | Moderate positive           |
# | +0.10 to +0.39      | Weak positive               |
# |  0                  | No correlation              |
# | -0.10 to -0.39      | Weak negative               |
# | -0.40 to -0.69      | Moderate negative           |
# | -0.70 to -0.89      | Strong negative             |
# | -0.90 to -1.00      | Very strong negative        |
#
# ---
#
# ## 🔹 Pearson Correlation Coefficient (r)
#
# ### ✅ Definition:
# - Measures the **strength and direction** of a **linear** relationship.
# - Most commonly used.
#
# ### 🧮 Formula:
# $$
# r = \frac{ \sum_{i=1}^n (X_i - \bar{X})(Y_i - \bar{Y}) }{ \sqrt{ \sum_{i=1}^n (X_i - \bar{X})^2 } \cdot \sqrt{ \sum_{i=1}^n (Y_i - \bar{Y})^2 } }
# $$

# %% [markdown]
# 🔍 What is Correlation?
# Correlation measures the strength and direction of a linear relationship between two variables.
#
# The correlation coefficient (r) ranges from -1 to +1:
#
# +1: Perfect positive correlation
#
# 0: No correlation
#
# -1: Perfect negative correlation
#
# ✅ Example-Based Detailed Conclusion Template
# Let’s say you analyzed two variables: Hours Studied (X) and Exam Scores (Y).
#
# Example Correlation Coefficient: r = +0.85
# Here is a detailed conclusion you could draw:
#
# The correlation coefficient between hours studied and exam scores is +0.85, indicating a strong positive linear relationship. This suggests that, in general, as the number of hours studied increases, exam scores tend to increase as well.
#
# While this correlation is strong, it is important to note that correlation does not imply causation. Other factors, such as prior knowledge, sleep, or exam difficulty, may also influence exam scores.
#
# Nonetheless, the data provides evidence that study time is a significant predictor of performance in this context. Therefore, encouraging students to invest more time in studying may potentially lead to improved academic outcomes.
#
# 🧠 What You Can Include in Any Conclusion:
# Strength: weak, moderate, strong
#
# Direction: positive or negative
#
# Linearity: whether it appears to be a linear relationship
#
# Statistical significance (if applicable): Was the result statistically significant (e.g., p-value)?
#
# Practical implications: What does this mean in real life or in decision-making?
#
# Limitations: Reminder that correlation ≠ causation
#
# Suggestions for further analysis: Consider regression or experiments for causal inference
#
# If you give me your actual data or variables involved, I can help you draft a customized and detailed conclusion.
#
#
#
#
# You said:
# in real world and how is that usefull for ml model
#
#
# ChatGPT said:
# Great question! Let’s explore how correlation is used in the real world and why it’s important for machine learning (ML) models.
#
# 🌍 Real-World Use of Correlation
# Correlation is widely used across many fields to understand relationships between variables, such as:
#
# Field	Example of Correlation Use
# Finance	Correlation between stock returns (e.g., Apple vs. Nasdaq index)
# Healthcare	Correlation between smoking and lung disease
# Marketing	Correlation between ad spend and sales revenue
# Education	Correlation between attendance and exam performance
# Social Science	Correlation between income level and education level
#
# 🧠 Why is that useful?
# Understanding correlation helps:
#
# Identify predictor variables for decision-making
#
# Avoid using redundant data
#
# Spot spurious relationships that might mislead analysis
#
# 🤖 How Correlation is Useful in Machine Learning
# 1. Feature Selection
# In ML, we often have many input variables (features). Correlation helps identify:
#
# Which features are strongly related to the target variable
#
# Which features are highly correlated with each other, which might cause multicollinearity (especially bad for linear models)
#
# 👉 Example:
# If two features are 95% correlated, keeping both may add noise. You might drop one to make the model more efficient and generalize better.
#
# 2. Model Simplification
# Removing correlated or irrelevant variables makes the model:
#
# Faster to train
#
# Easier to interpret
#
# Less prone to overfitting
#
# 3. Understanding Feature Impact
# Before training a model, correlation gives you a quick diagnostic of:
#
# Which features have predictive potential
#
# Whether a relationship is positive or negative
#
# 4. Choosing the Right Model
# Some models (like linear regression) assume no multicollinearity. If features are highly correlated:
#
# You may need to use dimensionality reduction (like PCA)
#
# Or choose tree-based models, which are more tolerant of correlation
#
# ⚠️ Important Caveat in ML:
# Correlation does not imply causation.
# In ML, we use correlation as a signal, but we don’t assume it's the cause. A feature could be strongly correlated with the target without being the real reason.
#
# ✅ Summary: Why Correlation is Useful in ML
# Benefit	How it Helps
# Feature selection	Keeps only useful predictors
# Avoid multicollinearity	Ensures model stability and interpretability
# Simplifies models	Fewer features = faster training and better generalization
# Improves performance	Removes noise from redundant data
# Supports exploratory data analysis (EDA)	Helps understand data before modeling

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('D:/Data Science/Datasets/movies.csv')

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
df.columns
# Out:
# Index(['name', 'rating', 'genre', 'year', 'released', 'score', 'votes',
#        'director', 'writer', 'star', 'country', 'budget', 'gross', 'company',
#        'runtime'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %% [markdown]
# # Correlation

# %% [markdown]
# * It shows the relation between two column (-1 to +1)

# %% [markdown]
# Now we are gonna only work on numerical data, so extracting it now

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB

# %% [markdown]
# Here we can see, float64 are the numerical data, therefore

# %%
num_df = df.select_dtypes('float64')
num_df
# Out:
#       score      votes      budget        gross  runtime
# 0       8.4   927000.0  19000000.0   46998772.0    146.0
# 1       5.8    65000.0   4500000.0   58853106.0    104.0
# 2       8.7  1200000.0  18000000.0  538375067.0    124.0
# 3       7.7   221000.0   3500000.0   83453539.0     88.0
# 4       7.3   108000.0   6000000.0   39846344.0     98.0
# ...     ...        ...         ...          ...      ...
# 7663    3.1       18.0      7000.0          NaN     90.0
# 7664    4.7       36.0         NaN          NaN     90.0
# 7665    5.7       29.0     58750.0          NaN      NaN
# 7666    NaN        NaN     15000.0          NaN    120.0
# 7667    5.7        7.0         NaN          NaN    102.0
#
# [7668 rows x 5 columns]

# %% [markdown]
# Therefore finding corelation between thise now

# %%
corelation = num_df.corr() # This is correlation
corelation
# Out:
#             score     votes    budget     gross   runtime
# score    1.000000  0.409182  0.076254  0.186258  0.399451
# votes    0.409182  1.000000  0.442429  0.630757  0.309212
# budget   0.076254  0.442429  1.000000  0.740395  0.320447
# gross    0.186258  0.630757  0.740395  1.000000  0.245216
# runtime  0.399451  0.309212  0.320447  0.245216  1.000000

# %%
covariance = num_df.cov() # covariance -infinity to infinity
covariance
# Out:
#                 score         votes        budget         gross       runtime
# score    9.386541e-01  6.474689e+04  3.062972e+06  2.972445e+07  7.192116e+00
# votes    6.474689e+04  2.667465e+10  3.367573e+12  1.722762e+13  9.386740e+05
# budget   3.062972e+06  3.367573e+12  1.718707e+15  5.755673e+15  2.413895e+08
# gross    2.972445e+07  1.722762e+13  5.755673e+15  2.746482e+16  7.523989e+08
# runtime  7.192116e+00  9.386740e+05  2.413895e+08  7.523989e+08  3.452628e+02

# %% [markdown]
# * Graphycial representation

# %%
sns.heatmap(corelation, annot=True) # For heatmap you need to pass two things (corelation , annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(covariance, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Practice

# %%
df = pd.read_csv('D:/Data Science/Datasets/movies.csv')
df.head(3)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
#
#          gross            company  runtime
# 0   46998772.0       Warner Bros.    146.0
# ...

# %%
df.isnull().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB

# %%
num_df = df.select_dtypes(['float64', 'int64'])
num_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   year     7668 non-null   int64
#  1   score    7665 non-null   float64
#  2   votes    7665 non-null   float64
#  3   budget   5497 non-null   float64
#  4   gross    7479 non-null   float64
#  5   runtime  7664 non-null   float64
# dtypes: float64(5), int64(1)
# memory usage: 359.6 KB

# %%
corr_ = num_df.corr()

# %%
sns.heatmap(corr_, annot=True)
# Out:
# <Axes: >
