# %% [markdown]
# # Silhouette score
# * After we do clustering to the data then how we need to know that the number of cluster we have got is corect or wrong
# * So Silhoutte score is a validation score hich tells use wheather our number of cluster is correct or not
# * ![image.png](attachment:96170579-d9ef-4129-a98f-518170315321.png)

# %% [markdown]
# **Formula**
# ![image.png](attachment:32b6b494-dd68-4e3e-beee-ab2c48c0c1d2.png)
#  ![image.png](attachment:fa9ceaa0-e035-4060-b86b-e4473c1b6c51.png)
# * 1 is best score
# * -1 is worst score

# %% [markdown]
# Check this afterwords
